# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# **To scrape the data we will use BeautifulSoup**

# %%
soup = BeautifulSoup("http", 'html.parser')

#Let's start on the main page of the website
URL = 'https://www.androidrank.org/android-most-popular-google-play-apps'
r = requests.get(URL)
page_body = r.text
soup = BeautifulSoup(page_body, 'html.parser')

# Initialization of an empty dataframe with the desired columns (URL is ou unique ID)
new_columns = ["URL", 'Rank','Name', 'Nb_Rating', 'Installs', 'Avg_Rating', "Ev_30", "Ev_60", "Price", "Category"]
app_pd = pd.DataFrame(columns=new_columns)

# We go throught all the categories and take all the given app and their ranking in that category
nav = soup.find("nav")
start = nav.find("b", text="Comics") #1
for b in start.find_next_siblings("b"):
    a = b.find("a")
    Category = a.get_text()
    
    # Now we move on the webpage of the desired category
    URL = 'https://www.androidrank.org/'+a["href"]
    r = requests.get(URL)
    page_body = r.text
    soup = BeautifulSoup(page_body, 'html.parser')
    
    # We select all the app on the webpage with all their informations
    table = soup.find("table", id="ranklist")
    apps = table.find_all("tr")[1:]
    for app in apps:
        
        # Ev_30 and Ev_60 corresponds to the growth of the number of ratings over the 30 and 60 respectively
        URL, Rank, Name, Nb_Rating, Installs, Avg_Rating, Ev_30, Ev_60, Price = '','','','','','','','',''
        p = app.find_all("td")
        Rank = p[0].text
        URL = p[1].find('a', href=True)["href"]
        Name = p[1].find('a', href=True).text
        Nb_Rating = p[3].text
        Installs = p[4].text
        Avg_Rating = p[5].text
        Ev_30 = p[6].text
        Ev_60 = p[7].text
        Price = p[8].text
        
        # We create a "dummy" dataframe to organize the collected data
        characteristics_pd = pd.DataFrame([[URL, Rank, Name, Nb_Rating, Installs, Avg_Rating,
                                            Ev_30, Ev_60, Price,Category]], columns = new_columns)
        
        # We append this dataframe to the global dataframe
        app_pd = app_pd.append(characteristics_pd,ignore_index=True)
    
    #we get the the URL for the next page in the same category
    nextpage = soup.find_all('small')[1].find("a", text="Next >")
    
    # We continue this until there is no next page in the given category anymore
    while(len(nextpage['href'])):
        
        urlnext_page = "https://www.androidrank.org" + nextpage['href']
        r = requests.get(urlnext_page)
        page_body = r.text
        soup = BeautifulSoup(page_body, 'html.parser')

        table = soup.find("table", id="ranklist")
        apps = table.find_all("tr")[1:]

        for app in apps:
            URL, Rank, Name, Nb_Rating, Installs, Avg_Rating, Ev_30, Ev_60, Price = '','','','','','','','',''
            p = app.find_all("td")
            Rank = p[0].text
            URL = p[1].find('a', href=True)["href"]
            Name = p[1].find('a', href=True).text
            Nb_Rating = p[3].text
            Installs = p[4].text
            Avg_Rating = p[5].text
            Ev_30 = p[6].text
            Ev_60 = p[7].text
            Price = p[8].text
            characteristics_pd = pd.DataFrame([[URL, Rank, Name, Nb_Rating, Installs, Avg_Rating,
                                                Ev_30, Ev_60, Price, Category]], columns = new_columns)
            app_pd = app_pd.append(characteristics_pd,ignore_index=True)
            
            # To avoid a crash due to the return of a None when there is no next page we manually set it to ""
            if(soup.find_all('small')[1].find("a", text="Next >")):
                nextpage = soup.find_all('small')[1].find("a", text="Next >")
            else:
                nextpage["href"] = ""
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-fbce7802a638> in <module>
#      44
#      45         table = soup.find("table", id="ranklist")
# ---> 46         apps = table.find_all("tr")[1:]
#      47
#      48
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %% [markdown]
# **Due to the excess of requests, we had to relaunch the previous cell and modify line #1 to restart from the desired category**

# %%
# Read the first csv containing data
df_app = pd.read_csv('data/1.csv', index_col=[0])

# Iterate through the 7 remaining files
for i in range(2,9):
    df_temp = pd.read_csv('data/' + str(i) + '.csv', index_col=[0])
    df_app = pd.concat([df_app, df_temp], ignore_index=True, join='inner')
    
# Dropping duplicates since the parsing was sometimes stopped during the analysis of one category of apps
df_app.drop_duplicates(inplace = True)
df_app.to_csv("data/final_dataset.csv")

# %% [markdown]
# **At the end we have the following datasets**

# %%
df_app = pd.read_csv('data/final_dataset.csv', index_col=[0])
df_app.head(10)
# Out:
#                                                  URL  Rank  \
# 0  /application/canva_graphic_design_video_invite...   1.0
# 1  /application/ibis_paint_x/jp.ne.ibis.ibispaint...   2.0
# 2  /application/kappboom_cool_wallpapers_backgrou...   3.0
# 3  /application/flipaclip_cartoon_animation/com.v...   4.0
# 4  /application/u_launcher_lite_new_3d_launcher_2...   5.0
# 5  /application/medibang_paint_make_art_/com.medi...   6.0
# 6  /application/u_launcher_3d_new_launcher_2019_3...   7.0
# 7       /application/papercolor/com.eyewind.paperone   8.0
# 8  /application/sand_draw_sketch_drawing_pad_crea...   9.0
# 9  /application/how_to_draw_graffitis/com.sweefit...  10.0
#
#                                                 Name  Nb_Rating Installs  \
# 0  Canva: Graphic Design, Video, Invite & Logo Maker  2,241,579   50.0 M
# 1                                       ibis Paint X    642,389   10.0 M
# 2  Kappboom - Cool Wallpapers & Background Wallpa...    399,327   10.0 M
# 3                       FlipaClip: Cartoon animation    319,841   10.0 M
# 4    U Launcher Lite-New 3D Launcher 2019, Hide apps    216,161   10.0 M
# 5                        MediBang Paint - Make Art !    194,262   10.0 M
# 6        U Launcher 3D: New Launcher 2019, 3d themes    130,195    5.0 M
# 7                                         PaperColor    111,058   10.0 M
# 8  Sand Draw Sketch Drawing Pad: Creative Doodle Art     99,055    5.0 M
# 9                              How to Draw Graffitis     94,175    5.0 M
#
#    Avg_Rating Ev_30 Ev_60 Price      Category
# 0        4.68  4.7%  8.8%  Free  Art & Design
# 1        4.45  4.4%  9.0%  Free  Art & Design
# 2        4.63  0.0%  0.0%  Free  Art & Design
# 3        4.28  1.5%  3.2%  Free  Art & Design
# 4        4.52  1.6%  3.4%  Free  Art & Design
# 5        4.10  1.2%  2.5%  Free  Art & Design
# 6        4.50  1.1%  2.0%  Free  Art & Design
# 7        4.23  1.9%  4.2%  Free  Art & Design
# 8        4.37  0.9%  1.9%  Free  Art & Design
# 9        4.33  0.2%  0.4%  Free  Art & Design

# %% [markdown]
# **Isn't it weird that we don't have 24 500 rows since we have a top 500 in each category and 49 categories?**
# **Let's have a closer look**

# %%
df_app.Category.value_counts().tail(10)
# Out:
# Game Racing      500
# Video Players    500
# Game Music       500
# Art & Design     500
# Game Card        500
# Dating           500
# House & Home     500
# Business         500
# Game Casual      500
# Events           297
# Name: Category, dtype: int64

# %% [markdown]
# **By looking on the website, we see that this is not a scraping problem but that some categories have less app in the Top. This is already a good thing to highlights the difference of diversity between each categories**

# %% [markdown]
# **Little bit of cleaning let's convert back the number from string to int**

# %%
df_app
# Out:
#                                                      URL   Rank  \
# 0      /application/canva_graphic_design_video_invite...    1.0
# 1      /application/ibis_paint_x/jp.ne.ibis.ibispaint...    2.0
# 2      /application/kappboom_cool_wallpapers_backgrou...    3.0
# 3      /application/flipaclip_cartoon_animation/com.v...    4.0
# 4      /application/u_launcher_lite_new_3d_launcher_2...    5.0
# 5      /application/medibang_paint_make_art_/com.medi...    6.0
# 6      /application/u_launcher_3d_new_launcher_2019_3...    7.0
# 7           /application/papercolor/com.eyewind.paperone    8.0
# 8      /application/sand_draw_sketch_drawing_pad_crea...    9.0
# 9      /application/how_to_draw_graffitis/com.sweefit...   10.0
# 10     /application/photo_sketch_photo_editor/com.swe...   11.0
# 11     /application/photo_cartoon_editor_effects_cart...   12.0
# 12     /application/textart_cool_text_creator/com.jdp...   13.0
# 13     /application/pixel_painter/com.DioAliasGames.M...   14.0
# 14     /application/easy_pose_best_posing_app/com.mad...   15.0
# 15     /application/ilauncher_for_os_12_stylish_theme...   16.0
# 16     /application/floor_plan_creator/pl.planmieszka...   17.0
# 17     /application/infinite_painter/com.brakefield.p...   18.0
# 18     /application/poster_maker_flyer_maker_2020_fre...   19.0
# 19     /application/penup_share_your_drawings/com.sec...   20.0
# 20     /application/tattoo_name_on_my_photo_editor/co...   21.0
# 21     /application/unwanted_object_remover_remove_ob...   22.0
# 22     /application/colorminis_3d_coloring_material_d...   23.0
# 23     /application/patternator_pattern_maker_backgro...   24.0
# 24     /application/infinite_design/com.brakefield.id...   25.0
# 25     /application/x_launcher_new_with_os12_style_th...   26.0
# 26     /application/anime_paint_by_numbers/zonek.desi...   27.0
# 27     /application/my_name_in_3d_live_wallpaper/com....   28.0
# 28     /application/x_launcher_lite_with_os12_style_t...   29.0
# 29     /application/stickdraw_animation_maker/com.bin...   30.0
# ...                                                  ...    ...
# 26107  /application/samsung_print_service_plugin/com....  471.0
# 26108  /application/subway_princess_runner/com.rioo.r...  472.0
# 26109  /application/tiktok_lite/com.zhiliaoapp.musica...  473.0
# 26110  /application/google_slides/com.google.android....  474.0
# 26111  /application/diskdigger_photo_recovery/com.def...  475.0
# 26112  /application/carrier_services/com.google.andro...  476.0
# 26113  /application/calculator_unit_converter/com.asu...  477.0
# 26114  /application/contacts/com.google.android.contacts  478.0
# 26115          /application/album/com.sonyericsson.album  479.0
# 26116  /application/google_go_a_lighter_faster_way_to...  480.0
# 26117          /application/music/com.sonyericsson.music  481.0
# 26118  /application/huawei_mobile_services/com.huawei...  482.0
# 26119  /application/phoenix_browser_video_download_pr...  483.0
# 26120    /application/clock/com.google.android.deskclock  484.0
# 26121  /application/free_video_downloader/free.video....  485.0
# 26122   /application/motorola_camera/com.motorola.camera  486.0
# 26123  /application/verizon_cloud/com.vcast.mediamanager  487.0
# 26124  /application/samsung_smart_switch_mobile/com.s...  488.0
# 26125  /application/ant_radio_service/com.dsi.ant.ser...  489.0
# 26126        /application/mi_telcel/com.speedymovil.wire  490.0
# 26127  /application/ant_plugins_service/com.dsi.ant.p...  491.0
# 26128  /application/device_care/com.samsung.android.lool  492.0
# 26129  /application/calculator/com.google.android.cal...  493.0
# 26130  /application/samsung_one_ui_home/com.sec.andro...  494.0
# 26131  /application/samsung_calculator/com.sec.androi...  495.0
# 26132  /application/samsung_notes/com.samsung.android...  496.0
# 26133  /application/samsung_my_files/com.sec.android....  497.0
# 26134  /application/samsung_voice_recorder/com.sec.an...  498.0
# 26135  /application/secure_folder/com.samsung.knox.se...  499.0
# 26136  /application/samsung_experience_service/com.sa...  500.0
#
#                                                     Name  Nb_Rating  Installs  \
# 0      Canva: Graphic Design, Video, Invite & Logo Maker  2,241,579    50.0 M
# 1                                           ibis Paint X    642,389    10.0 M
# 2      Kappboom - Cool Wallpapers & Background Wallpa...    399,327    10.0 M
# 3                           FlipaClip: Cartoon animation    319,841    10.0 M
# 4        U Launcher Lite-New 3D Launcher 2019, Hide apps    216,161    10.0 M
# 5                            MediBang Paint - Make Art !    194,262    10.0 M
# 6            U Launcher 3D: New Launcher 2019, 3d themes    130,195     5.0 M
# 7                                             PaperColor    111,058    10.0 M
# 8      Sand Draw Sketch Drawing Pad: Creative Doodle Art     99,055     5.0 M
# 9                                  How to Draw Graffitis     94,175     5.0 M
# 10                           Photo Sketch : Photo Editor     93,194    10.0 M
# 11     Photo Cartoon Editor & Effects : Cartoon Yourself     91,535     5.0 M
# 12                           TextArt ★ Cool Text creator     72,627    10.0 M
# 13                                         Pixel Painter     69,567     1.0 M
# 14                           Easy Pose - Best Posing App     66,355     5.0 M
# 15     iLauncher for OS 12 - Stylish Theme and Wallpaper     58,445     1.0 M
# 16                                    Floor Plan Creator     55,789    10.0 M
# 17                                      Infinite Painter     54,773     5.0 M
# 18     Poster Maker Flyer Maker 2020 free Ads Page De...     51,804     1.0 M
# 19                           PENUP - Share your drawings     49,818    50.0 M
# 20                        Tattoo Name On My Photo Editor     49,013    10.0 M
# 21     Unwanted Object Remover - Remove Object from P...     47,969     1.0 M
# 22       ColorMinis - 3D Coloring & Material Design Game     46,533     1.0 M
# 23     Patternator Pattern Maker Backgrounds & Wallpa...     45,557     1.0 M
# 24                                       Infinite Design     45,071     5.0 M
# 25                 X Launcher New: With OS12 Style Theme     44,325     1.0 M
# 26                              Anime - Paint by Numbers     43,825     1.0 M
# 27                          My Name in 3D Live Wallpaper     43,421     1.0 M
# 28     X Launcher Lite: With OS12 Style Theme & Wallp...     43,397     1.0 M
# 29                           StickDraw - Animation Maker     38,467     1.0 M
# ...                                                  ...        ...       ...
# 26107                       Samsung Print Service Plugin    356,642  1000.0 M
# 26108                             Subway Princess Runner    356,203   100.0 M
# 26109                                        TikTok Lite    354,582   100.0 M
# 26110                                      Google Slides    350,341   500.0 M
# 26111                          DiskDigger photo recovery    337,379   100.0 M
# 26112                                   Carrier Services    304,984   500.0 M
# 26113                        Calculator - unit converter    304,311   100.0 M
# 26114                                           Contacts    290,645   100.0 M
# 26115                                              Album    277,990   100.0 M
# 26116         Google Go: A lighter, faster way to search    271,833   100.0 M
# 26117                                              Music    269,355   100.0 M
# 26118                             Huawei Mobile Services    260,591   100.0 M
# 26119    Phoenix Browser -Video Download, Private & Fast    249,001   100.0 M
# 26120                                              Clock    248,081   500.0 M
# 26121                              Free Video Downloader    241,639   100.0 M
# 26122                                    Motorola Camera    234,972   100.0 M
# 26123                                      Verizon Cloud    224,233   100.0 M
# 26124                        Samsung Smart Switch Mobile    205,206   100.0 M
# 26125                                  ANT Radio Service    203,997  1000.0 M
# 26126                                          Mi Telcel    197,947   100.0 M
# 26127                               ANT+ Plugins Service    176,635  1000.0 M
# 26128                                        Device Care    174,452  1000.0 M
# 26129                                         Calculator    132,302   500.0 M
# 26130                                Samsung One UI Home    121,558  1000.0 M
# 26131                                 Samsung Calculator    119,958  1000.0 M
# 26132                                      Samsung Notes    102,307   500.0 M
# 26133                                   Samsung My Files     89,563  1000.0 M
# 26134                             Samsung Voice Recorder     83,886  1000.0 M
# 26135                                      Secure Folder     73,795   500.0 M
# 26136                         Samsung Experience Service     48,944   500.0 M
#
#        Avg_Rating  Ev_30  Ev_60 Price      Category
# 0            4.68   4.7%   8.8%  Free  Art & Design
# 1            4.45   4.4%   9.0%  Free  Art & Design
# 2            4.63   0.0%   0.0%  Free  Art & Design
# 3            4.28   1.5%   3.2%  Free  Art & Design
# 4            4.52   1.6%   3.4%  Free  Art & Design
# 5            4.10   1.2%   2.5%  Free  Art & Design
# 6            4.50   1.1%   2.0%  Free  Art & Design
# 7            4.23   1.9%   4.2%  Free  Art & Design
# 8            4.37   0.9%   1.9%  Free  Art & Design
# 9            4.33   0.2%   0.4%  Free  Art & Design
# 10           3.99   0.0%   0.0%  Free  Art & Design
# 11           2.76   0.3%   0.7%  Free  Art & Design
# 12           4.32   0.5%   0.9%  Free  Art & Design
# 13           3.75   0.5%   0.9%  Free  Art & Design
# 14           3.86   1.5%   2.3%  Free  Art & Design
# 15           4.65   3.6%   8.9%  Free  Art & Design
# 16           4.06   2.3%   4.4%  Free  Art & Design
# 17           3.87   2.8%   5.8%  Free  Art & Design
# 18           4.65  23.1%  55.1%  Free  Art & Design
# 19           4.75   8.1%  16.8%  Free  Art & Design
# 20           4.17   0.1%   0.4%  Free  Art & Design
# 21           3.76   3.3%   6.6%  Free  Art & Design
# 22           3.76   0.2%   0.3%  Free  Art & Design
# 23           2.79   0.3%   0.4%  Free  Art & Design
# 24           3.58   4.3%   7.5%  Free  Art & Design
# 25           4.50   1.4%   3.5%  Free  Art & Design
# 26           4.49   1.0%   2.9%  Free  Art & Design
# 27           4.55   7.3%  14.0%  Free  Art & Design
# 28           4.49   1.9%   3.8%  Free  Art & Design
# 29           3.70   0.2%   0.5%  Free  Art & Design
# ...           ...    ...    ...   ...           ...
# 26107        4.26   1.2%   1.7%  Free           NaN
# 26108        4.13   3.5%   7.2%  Free           NaN
# 26109        4.16  11.3%  24.8%  Free           NaN
# 26110        4.29   1.8%   3.0%  Free           NaN
# 26111        3.98   1.1%   2.3%  Free           NaN
# 26112        4.40   7.4%  11.9%  Free           NaN
# 26113        4.66   0.2%   0.4%  Free           NaN
# 26114        4.32   6.0%  11.0%  Free           NaN
# 26115        4.23   0.3%   0.7%  Free           NaN
# 26116        4.37   7.9%  14.7%  Free           NaN
# 26117        3.94   0.7%   1.0%  Free           NaN
# 26118        3.92   6.1%  12.4%  Free           NaN
# 26119        4.63   7.8%  14.4%  Free           NaN
# 26120        3.94   2.3%   3.7%  Free           NaN
# 26121        4.16   3.8%   8.4%  Free           NaN
# 26122        3.34   0.2%   0.3%  Free           NaN
# 26123        4.58   0.6%   1.1%  Free           NaN
# 26124        4.39   1.8%   3.5%  Free           NaN
# 26125        4.00   2.4%   3.4%  Free           NaN
# 26126        3.08   6.4%  12.7%  Free           NaN
# 26127        4.01   2.6%   3.6%  Free           NaN
# 26128        4.23   9.9%  14.9%  Free           NaN
# 26129        4.42   6.5%   9.9%  Free           NaN
# 26130        4.17   7.2%  12.4%  Free           NaN
# 26131        4.57   9.7%  18.0%  Free           NaN
# 26132        4.37  10.7%  17.6%  Free           NaN
# 26133        4.40   9.0%  14.3%  Free           NaN
# 26134        4.38   4.7%   6.6%  Free           NaN
# 26135        4.22   8.5%  14.7%  Free           NaN
# 26136        4.30  14.7%  27.3%  Free           NaN
#
# [24797 rows x 10 columns]

# %%
df_app["Nb_Rating"] = df_app["Nb_Rating"].str.replace(',', '')
df_app["Nb_Rating"] = df_app["Nb_Rating"].astype(int)
df_app["Installs"] = df_app["Installs"].str.replace(' ', '')
df_app["Installs"] = (df_app["Installs"].str.replace(r'[kM]+$', '', regex=True).astype(float) * \
                        df_app["Installs"].str.extract(r'[\d\.]+([kM]+)', expand=False)
                         .fillna(1)
                          .replace(['k','M'], [10**3, 10**6]).astype(int))
df_app["Avg_Rating"] = df_app["Avg_Rating"].astype(float)
df_app["Nb_Rating"] = df_app["Nb_Rating"].astype(int)
df_app["Installs"] = df_app["Installs"].str.replace(' ', '')
df_app.head(5)
# Out:
#                                                  URL  Rank  \
# 0  /application/canva_graphic_design_video_invite...   1.0
# 1  /application/ibis_paint_x/jp.ne.ibis.ibispaint...   2.0
# 2  /application/kappboom_cool_wallpapers_backgrou...   3.0
# 3  /application/flipaclip_cartoon_animation/com.v...   4.0
# 4  /application/u_launcher_lite_new_3d_launcher_2...   5.0
#
#                                                 Name  Nb_Rating    Installs  \
# 0  Canva: Graphic Design, Video, Invite & Logo Maker    2241579  50000000.0
# 1                                       ibis Paint X     642389  10000000.0
# 2  Kappboom - Cool Wallpapers & Background Wallpa...     399327  10000000.0
# 3                       FlipaClip: Cartoon animation     319841  10000000.0
# 4    U Launcher Lite-New 3D Launcher 2019, Hide apps     216161  10000000.0
#
#    Avg_Rating Ev_30 Ev_60 Price      Category
# 0        4.68  4.7%  8.8%  Free  Art & Design
# 1        4.45  4.4%  9.0%  Free  Art & Design
# 2        4.63  0.0%  0.0%  Free  Art & Design
# 3        4.28  1.5%  3.2%  Free  Art & Design
# 4        4.52  1.6%  3.4%  Free  Art & Design

# %% [markdown]
# **Now let's see the repartion of the free and paid app on the Google Play Store**

# %%
df_app["Price"].value_counts().head(10)
# Out:
# Free     24672
# $4.99       23
# $0.99       19
# $2.99       18
# $1.99       15
# $3.99       10
# $6.99        5
# $9.99        4
# $5.99        4
# $2.49        4
# Name: Price, dtype: int64

# %%
np.shape(app_pd[app_pd["Price"]=="Free"])[0]
# Out:
# 2892

# %%
labels = 'Free', 'Paid'
explode = (0.1,0) #In order to highlights Free app

fig, ax = plt.subplots()
ax.pie([np.shape(app_pd[app_pd["Price"]=="Free"])[0], np.shape(app_pd[app_pd["Price"]!="Free"])[0]],
           explode=explode, labels=labels, autopct='%1.1f%%',
            shadow=True, startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# **Now let's see this distribution over all the categories**

# %%
np.shape(app_pd[(app_pd["Price"]=="Free") & (app_pd["Category"]=="Education")])[0]
# Out:
# 500

# %%
free = []
paid = []
for category in app_pd.Category.unique():
    free_cat = np.shape(app_pd[(app_pd["Price"]=="Free") & (app_pd["Category"]== category)])[0]
    paid_cat = np.shape(app_pd[(app_pd["Price"]!="Free") & (app_pd["Category"]== category)])[0]
    free.append(free_cat/(free_cat+payd_cat)*100)
    paid.append((paid_cat/(free_cat+payd_cat))*100)
ind = np.arange(len(app_pd.Category.unique()))    
width = 0.1      
plt.figure(figsize=(20,10))
p1 = plt.bar(ind, free, width,)
p2 = plt.bar(ind, paid, width,
             bottom=free)

plt.ylabel("Percentage")
plt.title('Scores by group and gender')
plt.xticks(ind, app_pd.Category.unique())
plt.yticks(np.arange(0, 101, 10))
plt.legend((p1[0], p2[0]), ('Free', 'Paid'))

plt.show()

# %% [markdown]
# # Analysis

# %% [markdown]
# **Thanks to an API on the same website we can also get more detailled information but it is limited to 100 requests per hour**
#
# **These cells will be explored later to get more information for the best ranked app in the overall ranking**

# %%
import requests
website = "https://www.androidrank.org/api/application/"
app = "com.facebook.katana"
key = "60lnc52x178li1rocmpum3829kdf6d9wt3dp7lqg7vxmqat6ov9ekcoipmqyuzpa"
search = website+app+"?key="+key;
response = requests.get(search)

# %%
response.json()
# Out:
# {'category': 'Social',
#  'category_rank': {'current': []},
#  'developer': {'developer_id': 'Facebook', 'name': 'Facebook'},
#  'id': 'com.facebook.katana',
#  'images': {'logo': 'https://lh3.googleusercontent.com/ccWDU4A7fX1R24v-vvT480ySh26AYp97g1VrIB_FIdjRcuQB2JP2WdY7h_wVVAeSpg',
#   'screenshots': ['https://lh3.googleusercontent.com/JelCBr0rDjDEGOqYb4m2Z7OSVBxS5KyqO94eW5TGnQtHc9k08uaMZVTz6s_rKha31eE',
#    'https://lh3.googleusercontent.com/Iomoub5EHkAk1_bKqIyjkFbKQ4vw-zFfTqfUMG_da-4-hV_tXwvuiFQUQWIeol_fRSo',
#    'https://lh3.googleusercontent.com/Jx0nPnGaGNRXCHlmGv13gDsIzhLykgkza5y2SUNruZoiwcik5lQ-gj99vdHZA0Zlbtrz',
#    'https://lh3.googleusercontent.com/YBTVMqZcl-t16dnH7_DxHsMm7WU2v2HdZRX3Q3UnYHXo8HUfQSuN2Ahn_M4KQunbeigu',
#    'https://lh3.googleusercontent.com/o4enSNrWkR4F6wILxPk6-6XkNyea4j9tcn8gLPphbBvhpp4_HBU9NNuQnhzreYH5uSN0']},
#  'installs': {'current': {'count': '5000000000'},
#   'history': [{'count': 5000000000, 'date': '2019-10-16'},
#    {'count': 1000000000, 'date': '2014-08-28'},
#    {'count': 500000000, 'date': '2013-08-11'},
#    {'count': 100000000, 'date': '2012-03-19'}]},
#  'name': 'Facebook',
#  'price': {'current': 'Free', 'history': {}},
#  'ratings': {'current': {'count': 96409662,
#    'rank1': 10142238,
#    'rank2': 3206283,
#    'rank3': 6224566,
#    'rank4': 10585962,
#    'rank5': 66250611},
#   'history': [{'count': 2062012,
#     'date': '2011-12-10',
#     'rank1': 342439,
#     'rank2': 143543,
#     'rank3': 302138,
#     'rank4': 406804,
#     'rank5': 867088},
#    {'count': 2417333,
#     'date': '2012-01-31',
#     'rank1': 425180,
#     'rank2': 166370,
#     'rank3': 344387,
#     'rank4': 462007,
#     'rank5': 1019389},
#    {'count': 2859915,
#     'date': '2012-04-10',
#     'rank1': 545768,
#     'rank2': 198176,
#     'rank3': 394451,
#     'rank4': 520301,
#     'rank5': 1201219},
#    {'count': 4166953,
#     'date': '2012-07-27',
#     'rank1': 807359,
#     'rank2': 281043,
#     'rank3': 540102,
#     'rank4': 710864,
#     'rank5': 1827585},
#    {'count': 5845635,
#     'date': '2012-12-26',
#     'rank1': 1115742,
#     'rank2': 373952,
#     'rank3': 709624,
#     'rank4': 949370,
#     'rank5': 2696947},
#    {'count': 6683229,
#     'date': '2013-04-19',
#     'rank1': 1327177,
#     'rank2': 426927,
#     'rank3': 791115,
#     'rank4': 1053249,
#     'rank5': 3084761},
#    {'count': 7920882,
#     'date': '2013-08-20',
#     'rank1': 1513939,
#     'rank2': 480873,
#     'rank3': 911876,
#     'rank4': 1233497,
#     'rank5': 3780697},
#    {'count': 9587977,
#     'date': '2013-12-17',
#     'rank1': 1694438,
#     'rank2': 541257,
#     'rank3': 1060350,
#     'rank4': 1469821,
#     'rank5': 4822111},
#    {'count': 15596972,
#     'date': '2014-04-28',
#     'rank1': 2198763,
#     'rank2': 779013,
#     'rank3': 1559889,
#     'rank4': 2511749,
#     'rank5': 8547558},
#    {'count': 21761377,
#     'date': '2014-10-07',
#     'rank1': 2817227,
#     'rank2': 1057347,
#     'rank3': 2103259,
#     'rank4': 3508218,
#     'rank5': 12275326},
#    {'count': 26928996,
#     'date': '2015-03-20',
#     'rank1': 3409821,
#     'rank2': 1318887,
#     'rank3': 2565197,
#     'rank4': 4315465,
#     'rank5': 15319626},
#    {'count': 31595466,
#     'date': '2015-09-02',
#     'rank1': 4015374,
#     'rank2': 1544422,
#     'rank3': 2970120,
#     'rank4': 5001540,
#     'rank5': 18064010},
#    {'count': 38148320,
#     'date': '2016-03-11',
#     'rank1': 5162449,
#     'rank2': 1868044,
#     'rank3': 3526208,
#     'rank4': 5931538,
#     'rank5': 21660081},
#    {'count': 47069108,
#     'date': '2016-08-16',
#     'rank1': 6200909,
#     'rank2': 2247659,
#     'rank3': 4354540,
#     'rank4': 7431883,
#     'rank5': 26834117},
#    {'count': 60886789,
#     'date': '2017-02-11',
#     'rank1': 7650548,
#     'rank2': 2797807,
#     'rank3': 5623880,
#     'rank4': 9662396,
#     'rank5': 35152158},
#    {'count': 70248234,
#     'date': '2017-09-01',
#     'rank1': 8525828,
#     'rank2': 3060924,
#     'rank3': 6372573,
#     'rank4': 10957545,
#     'rank5': 41331364},
#    {'count': 75155211,
#     'date': '2018-03-11',
#     'rank1': 9051732,
#     'rank2': 3212541,
#     'rank3': 6726316,
#     'rank4': 11517871,
#     'rank5': 44646751},
#    {'count': 78988863,
#     'date': '2018-09-23',
#     'rank1': 9518877,
#     'rank2': 3320559,
#     'rank3': 6986728,
#     'rank4': 11918853,
#     'rank5': 47243846},
#    {'count': 88132019,
#     'date': '2019-06-18',
#     'rank1': 10292692,
#     'rank2': 3551020,
#     'rank3': 7592992,
#     'rank4': 12927234,
#     'rank5': 53768081},
#    {'count': 96409660,
#     'date': '2020-03-15',
#     'rank1': 10142238,
#     'rank2': 3206283,
#     'rank3': 6224566,
#     'rank4': 10585962,
#     'rank5': 66250611}]}}
