# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# **To scrape the data we will use BeautifulSoup**

# %%
soup = BeautifulSoup("http", 'html.parser')

#Let's start on the main page of the website
URL = 'https://www.androidrank.org/android-most-popular-google-play-apps'
r = requests.get(URL)
page_body = r.text
soup = BeautifulSoup(page_body, 'html.parser')

# Initialization of an empty dataframe with the desired columns (URL is ou unique ID)
new_columns = ["URL", 'Rank','Name', 'Nb_Rating', 'Installs', 'Avg_Rating', "Ev_30", "Ev_60", "Price", "Category"]
app_pd = pd.DataFrame(columns=new_columns)

# We go throught all the categories and take all the given app and their ranking in that category
nav = soup.find("nav")
start = nav.find("b", text="Comics") #1
for b in start.find_next_siblings("b"):
    a = b.find("a")
    Category = a.get_text()
    
    # Now we move on the webpage of the desired category
    URL = 'https://www.androidrank.org/'+a["href"]
    r = requests.get(URL)
    page_body = r.text
    soup = BeautifulSoup(page_body, 'html.parser')
    
    # We select all the app on the webpage with all their informations
    table = soup.find("table", id="ranklist")
    apps = table.find_all("tr")[1:]
    for app in apps:
        
        # Ev_30 and Ev_60 corresponds to the growth of the number of ratings over the 30 and 60 respectively
        URL, Rank, Name, Nb_Rating, Installs, Avg_Rating, Ev_30, Ev_60, Price = '','','','','','','','',''
        p = app.find_all("td")
        Rank = p[0].text
        URL = p[1].find('a', href=True)["href"]
        Name = p[1].find('a', href=True).text
        Nb_Rating = p[3].text
        Installs = p[4].text
        Avg_Rating = p[5].text
        Ev_30 = p[6].text
        Ev_60 = p[7].text
        Price = p[8].text
        
        # We create a "dummy" dataframe to organize the collected data
        characteristics_pd = pd.DataFrame([[URL, Rank, Name, Nb_Rating, Installs, Avg_Rating,
                                            Ev_30, Ev_60, Price,Category]], columns = new_columns)
        
        # We append this dataframe to the global dataframe
        app_pd = app_pd.append(characteristics_pd,ignore_index=True)
    
    #we get the the URL for the next page in the same category
    nextpage = soup.find_all('small')[1].find("a", text="Next >")
    
    # We continue this until there is no next page in the given category anymore
    while(len(nextpage['href'])):
        
        urlnext_page = "https://www.androidrank.org" + nextpage['href']
        r = requests.get(urlnext_page)
        page_body = r.text
        soup = BeautifulSoup(page_body, 'html.parser')

        table = soup.find("table", id="ranklist")
        apps = table.find_all("tr")[1:]

        for app in apps:
            URL, Rank, Name, Nb_Rating, Installs, Avg_Rating, Ev_30, Ev_60, Price = '','','','','','','','',''
            p = app.find_all("td")
            Rank = p[0].text
            URL = p[1].find('a', href=True)["href"]
            Name = p[1].find('a', href=True).text
            Nb_Rating = p[3].text
            Installs = p[4].text
            Avg_Rating = p[5].text
            Ev_30 = p[6].text
            Ev_60 = p[7].text
            Price = p[8].text
            characteristics_pd = pd.DataFrame([[URL, Rank, Name, Nb_Rating, Installs, Avg_Rating,
                                                Ev_30, Ev_60, Price, Category]], columns = new_columns)
            app_pd = app_pd.append(characteristics_pd,ignore_index=True)
            
            # To avoid a crash due to the return of a None when there is no next page we manually set it to ""
            if(soup.find_all('small')[1].find("a", text="Next >")):
                nextpage = soup.find_all('small')[1].find("a", text="Next >")
            else:
                nextpage["href"] = ""
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-fbce7802a638> in <module>
#      44
#      45         table = soup.find("table", id="ranklist")
# ---> 46         apps = table.find_all("tr")[1:]
#      47
#      48
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %% [markdown]
# **Due to the excess of requests, we had to relaunch the previous cell and modify line #1 to restart from the desired category**

# %%
# Read the first csv containing data
df_app = pd.read_csv('data/1.csv', index_col=[0])

# Iterate through the 7 remaining files
for i in range(2,9):
    df_temp = pd.read_csv('data/' + str(i) + '.csv', index_col=[0])
    df_app = pd.concat([df_app, df_temp], ignore_index=True, join='inner')
    
# Dropping duplicates since the parsing was sometimes stopped during the analysis of one category of apps
df_app.drop_duplicates(inplace = True)
df_app.to_csv("data/final_dataset.csv")

# %% [markdown]
# **At the end we have the following datasets**

# %%
df_app = pd.read_csv('data/final_dataset.csv', index_col=[0])
df_app.head(10)
# Out:
#                                                  URL  Rank  \
# 0  /application/canva_graphic_design_video_invite...   1.0
# 1  /application/ibis_paint_x/jp.ne.ibis.ibispaint...   2.0
# 2  /application/kappboom_cool_wallpapers_backgrou...   3.0
# 3  /application/flipaclip_cartoon_animation/com.v...   4.0
# 4  /application/u_launcher_lite_new_3d_launcher_2...   5.0
# 5  /application/medibang_paint_make_art_/com.medi...   6.0
# 6  /application/u_launcher_3d_new_launcher_2019_3...   7.0
# 7       /application/papercolor/com.eyewind.paperone   8.0
# 8  /application/sand_draw_sketch_drawing_pad_crea...   9.0
# 9  /application/how_to_draw_graffitis/com.sweefit...  10.0
#
#                                                 Name  Nb_Rating Installs  \
# 0  Canva: Graphic Design, Video, Invite & Logo Maker  2,241,579   50.0 M
# 1                                       ibis Paint X    642,389   10.0 M
# 2  Kappboom - Cool Wallpapers & Background Wallpa...    399,327   10.0 M
# 3                       FlipaClip: Cartoon animation    319,841   10.0 M
# 4    U Launcher Lite-New 3D Launcher 2019, Hide apps    216,161   10.0 M
# 5                        MediBang Paint - Make Art !    194,262   10.0 M
# 6        U Launcher 3D: New Launcher 2019, 3d themes    130,195    5.0 M
# 7                                         PaperColor    111,058   10.0 M
# 8  Sand Draw Sketch Drawing Pad: Creative Doodle Art     99,055    5.0 M
# 9                              How to Draw Graffitis     94,175    5.0 M
#
#    Avg_Rating Ev_30 Ev_60 Price      Category
# 0        4.68  4.7%  8.8%  Free  Art & Design
# 1        4.45  4.4%  9.0%  Free  Art & Design
# 2        4.63  0.0%  0.0%  Free  Art & Design
# 3        4.28  1.5%  3.2%  Free  Art & Design
# 4        4.52  1.6%  3.4%  Free  Art & Design
# 5        4.10  1.2%  2.5%  Free  Art & Design
# 6        4.50  1.1%  2.0%  Free  Art & Design
# 7        4.23  1.9%  4.2%  Free  Art & Design
# 8        4.37  0.9%  1.9%  Free  Art & Design
# 9        4.33  0.2%  0.4%  Free  Art & Design

# %%
print('URL: ' + str(df_app.URL.isnull().values.any()))
print('Rank: ' + str(df_app.Rank.isnull().values.any()))
print('Name: ' + str(df_app.Name.isnull().values.any()))
print('Nb_Rating: ' + str(df_app.Nb_Rating.isnull().values.any()))
print('Installs: ' + str(df_app.Installs.isnull().values.any()))
print('Avg_Rating: ' + str(df_app.Avg_Rating.isnull().values.any()))
print('Ev_30: ' + str(df_app.Ev_30.isnull().values.any()))
print('Ev_60: ' + str(df_app.Ev_60.isnull().values.any()))
print('Price: ' + str(df_app.Price.isnull().values.any()))
print('Category: ' + str(df_app.Category.isnull().values.any()))
# Out:
# URL: False
# Rank: False
# Name: False
# Nb_Rating: False
# Installs: False
# Avg_Rating: False
# Ev_30: False
# Ev_60: False
# Price: False
# Category: True

# %% [markdown]
# **The only column with null values is the Category. It corresponds to the global ranking of all apps that were parsed, where the category was not mentionned. Since these apps already appear in their own category (if they are in the global top 500, they are also in their own category top 500), they are duplicates. So let's drop them.**

# %%
df_app.dropna(inplace=True)
df_app.isna().values.any()
# Out:
# False

# %% [markdown]
# **Isn't it weird that we don't have 24 500 rows since we have a top 500 in each category and 49 categories?**
# **Let's have a closer look**

# %%
df_app.Category.value_counts().tail(10)
# Out:
# Art & Design         500
# Education            500
# Game Card            500
# Game Educational     500
# Social               500
# Game Simulation      500
# Auto & Vehicles      500
# Maps & Navigation    500
# Game Board           500
# Events               297
# Name: Category, dtype: int64

# %% [markdown]
# **By looking on the website, we see that this is not a scraping problem but that some categories have less app in the Top. This is already a good thing to highlights the difference of diversity between each categories**

# %% [markdown]
# **Little bit of cleaning let's convert back the number from string to int**

# %%
df_app["Nb_Rating"] = df_app["Nb_Rating"].str.replace(',', '')
df_app["Nb_Rating"] = df_app["Nb_Rating"].astype(int)
df_app["Installs"] = df_app["Installs"].str.replace(' ', '')
df_app["Installs"] = (df_app["Installs"].str.replace(r'[kM]+$', '', regex=True).astype(float) * \
                        df_app["Installs"].str.extract(r'[\d\.]+([kM]+)', expand=False)
                         .fillna(1)
                          .replace(['k','M'], [10**3, 10**6]).astype(int))
df_app["Avg_Rating"] = df_app["Avg_Rating"].astype(float)
df_app["Ev_30"] = df_app["Ev_30"].str.replace('%', '').astype(float)
df_app["Ev_60"] = df_app["Ev_60"].str.replace('%', '').astype(float)
df_app.head(5)
# Out:
#                                                  URL  Rank  \
# 0  /application/canva_graphic_design_video_invite...   1.0
# 1  /application/ibis_paint_x/jp.ne.ibis.ibispaint...   2.0
# 2  /application/kappboom_cool_wallpapers_backgrou...   3.0
# 3  /application/flipaclip_cartoon_animation/com.v...   4.0
# 4  /application/u_launcher_lite_new_3d_launcher_2...   5.0
#
#                                                 Name  Nb_Rating    Installs  \
# 0  Canva: Graphic Design, Video, Invite & Logo Maker    2241579  50000000.0
# 1                                       ibis Paint X     642389  10000000.0
# 2  Kappboom - Cool Wallpapers & Background Wallpa...     399327  10000000.0
# 3                       FlipaClip: Cartoon animation     319841  10000000.0
# 4    U Launcher Lite-New 3D Launcher 2019, Hide apps     216161  10000000.0
#
#    Avg_Rating  Ev_30  Ev_60 Price      Category
# 0        4.68    4.7    8.8  Free  Art & Design
# 1        4.45    4.4    9.0  Free  Art & Design
# 2        4.63    0.0    0.0  Free  Art & Design
# 3        4.28    1.5    3.2  Free  Art & Design
# 4        4.52    1.6    3.4  Free  Art & Design

# %% [markdown]
# **Now let's see the repartion of the free and paid app on the Google Play Store**

# %%
df_app["Price"].value_counts().head(10)
# Out:
# Free     24172
# $4.99       23
# $0.99       19
# $2.99       18
# $1.99       15
# $3.99       10
# $6.99        5
# $5.99        4
# $2.49        4
# $9.99        4
# Name: Price, dtype: int64

# %%
labels = 'Free', 'Paid'
explode = (0.1,0) #In order to highlights Free app

fig, ax = plt.subplots()
ax.pie([np.shape(df_app[df_app["Price"]=="Free"])[0], np.shape(df_app[df_app["Price"]!="Free"])[0]],
           explode=explode, labels=labels, autopct='%1.1f%%',
            shadow=True, startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# **Now let's see this distribution over all the categories**

# %%
free = []
paid = []
label =[]
for category in df_app.Category.unique():
    free_cat = np.shape(df_app[(df_app["Price"]=="Free") & (df_app["Category"]== category)])[0]
    paid_cat = np.shape(df_app[(df_app["Price"]!="Free") & (df_app["Category"]== category)])[0]
    if((paid_cat/(free_cat+paid_cat))*100 >=1):
        label.append(category)
        free.append(free_cat/(free_cat+paid_cat)*100)
        paid.append((paid_cat/(free_cat+paid_cat))*100)
ind = np.arange(len(free))    
width = 0.4      
plt.figure(figsize=(20,10))
p1 = plt.bar(ind, free, width,)
p2 = plt.bar(ind, paid, width,
             bottom=free)

plt.ylabel("Percentage")
plt.title('Percentage of Free app in the most "expensive" categories')
plt.xticks(ind, label)
plt.yticks(np.arange(0, 101, 10))
plt.legend((p1[0], p2[0]), ('Free', 'Paid'))

plt.show()

# %%
df_app["Nb_Rating"].describe()
# Out:
# count    2.429700e+04
# mean     1.925593e+05
# std      1.582275e+06
# min      1.000000e+02
# 25%      8.224000e+03
# 50%      3.152900e+04
# 75%      9.441100e+04
# max      1.068849e+08
# Name: Nb_Rating, dtype: float64

# %%
df_app["Installs"].describe()
# Out:
# count    2.429700e+04
# mean     1.089308e+07
# std      1.202531e+08
# min      1.000000e+00
# 25%      1.000000e+06
# 50%      1.000000e+06
# 75%      5.000000e+06
# max      5.000000e+09
# Name: Installs, dtype: float64

# %%
df_app[df_app["Installs"]== df_app["Installs"].max()]
# Out:
#                                                      URL  Rank  \
# 3000        /application/whatsapp_messenger/com.whatsapp   1.0
# 3003   /application/google_chrome_fast_secure/com.and...   4.0
# 3009            /application/gmail/com.google.android.gm  10.0
# 9499   /application/google_play_music/com.google.andr...   3.0
# 12458  /application/google_drive/com.google.android.a...   2.0
# 13457          /application/facebook/com.facebook.katana   1.0
# 14457  /application/google_play_services/com.google.a...   1.0
# 14459  /application/google/com.google.android.googleq...   3.0
# 14478  /application/android_accessibility_suite/com.g...  22.0
# 14481  /application/google_text_to_speech/com.google....  25.0
# 15017  /application/maps_navigate_explore/com.google....   1.0
# 15517    /application/youtube/com.google.android.youtube   1.0
#
#                                Name  Nb_Rating      Installs  Avg_Rating  \
# 3000             WhatsApp Messenger  106884902  5.000000e+09        4.29
# 3003   Google Chrome: Fast & Secure   19578408  5.000000e+09        4.37
# 3009                          Gmail    6743557  5.000000e+09        4.40
# 9499              Google Play Music    4382860  5.000000e+09        4.10
# 12458                  Google Drive    5081538  5.000000e+09        4.39
# 13457                      Facebook   96409662  5.000000e+09        4.24
# 14457          Google Play services   28257988  5.000000e+09        4.26
# 14459                        Google   13997467  5.000000e+09        4.41
# 14478   Android Accessibility Suite    1830589  5.000000e+09        4.36
# 14481         Google Text-to-Speech    1661524  5.000000e+09        4.35
# 15017     Maps - Navigate & Explore   11175295  5.000000e+09        4.33
# 15517                       YouTube   67255190  5.000000e+09        4.14
#
#        Ev_30  Ev_60 Price        Category
# 3000     1.8    3.4  Free   Communication
# 3003     2.9    5.6  Free   Communication
# 3009     1.7    2.9  Free   Communication
# 9499     1.1    1.9  Free   Music & Audio
# 12458    2.5    4.7  Free    Productivity
# 13457    0.9    1.9  Free          Social
# 14457    1.6    3.5  Free           Tools
# 14459    2.1    3.9  Free           Tools
# 14478    2.2    3.4  Free           Tools
# 14481    2.3    3.5  Free           Tools
# 15017    1.1    1.9  Free  Travel & Local
# 15517    2.2    4.0  Free   Video Players

# %%
df_app.sort_values(["Nb_Rating", "Installs"], ascending = False).head(10)
# Out:
#                                                      URL  Rank  \
# 3000        /application/whatsapp_messenger/com.whatsapp   1.0
# 13457          /application/facebook/com.facebook.katana   1.0
# 13458       /application/instagram/com.instagram.android   2.0
# 3001   /application/messenger_text_and_video_chat_for...   2.0
# 15517    /application/youtube/com.google.android.youtube   1.0
# 23957  /application/clash_of_clans/com.supercell.clas...   1.0
# 16517  /application/garena_free_fire_kalahari/com.dts...   1.0
# 17957   /application/subway_surfers/com.kiloo.subwaysurf   1.0
# 14457  /application/google_play_services/com.google.a...   1.0
# 23958  /application/clash_royale/com.supercell.clashr...   2.0
#
#                                            Name  Nb_Rating      Installs  \
# 3000                         WhatsApp Messenger  106884902  5.000000e+09
# 13457                                  Facebook   96409662  5.000000e+09
# 13458                                 Instagram   95806924  1.000000e+09
# 3001   Messenger – Text and Video Chat for Free   71185969  1.000000e+09
# 15517                                   YouTube   67255190  5.000000e+09
# 23957                            Clash of Clans   51568217  5.000000e+08
# 16517                Garena Free Fire: Kalahari   43395207  5.000000e+08
# 17957                            Subway Surfers   32200740  1.000000e+09
# 14457                      Google Play services   28257988  5.000000e+09
# 23958                              Clash Royale   28254261  1.000000e+08
#
#        Avg_Rating  Ev_30  Ev_60 Price       Category         Score  \
# 3000         4.29    1.8    3.4  Free  Communication  4.585362e+08
# 13457        4.24    0.9    1.9  Free         Social  4.087770e+08
# 13458        4.46    1.4    2.8  Free         Social  4.272989e+08
# 3001         4.24    0.5    1.1  Free  Communication  3.018285e+08
# 15517        4.14    2.2    4.0  Free  Video Players  2.784365e+08
# 23957        4.51    0.3    0.7  Free  Game Strategy  2.325727e+08
# 16517        4.36    5.5    8.4  Free    Game Action  1.892031e+08
# 17957        4.47    0.6    1.3  Free    Game Arcade  1.439373e+08
# 14457        4.26    1.6    3.5  Free          Tools  1.203790e+08
# 23958        4.26    0.5    1.0  Free  Game Strategy  1.203632e+08
#
#        Global_rank
# 3000           1.0
# 13457          3.0
# 13458          2.0
# 3001           4.0
# 15517          5.0
# 23957          6.0
# 16517          7.0
# 17957          8.0
# 14457         10.0
# 23958         11.0

# %%
df_app["Ev_30_norm"] = df_app["Ev_30"]*df_app["Nb_Rating"]
df_app["Ev_60_norm"] = df_app["Ev_60"]*df_app["Nb_Rating"]

# %%
df_app.Category.unique()
# Out:
# array(['Art & Design', 'Auto & Vehicles', 'Beauty', 'Books & Reference',
#        'Business', 'Comics', 'Communication', 'Dating', 'Education',
#        'Entertainment', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Maps & Navigation', 'Medical', 'Music & Audio',
#        'News & Magazines', 'Parenting', 'Personalization', 'Photography',
#        'Productivity', 'Shopping', 'Social', 'Sports', 'Tools',
#        'Travel & Local', 'Video Players', 'Weather', 'Game Action',
#        'Game Adventure', 'Game Arcade', 'Game Board', 'Game Card',
#        'Game Casino', 'Game Casual', 'Game Educational', 'Game Music',
#        'Game Puzzle', 'Game Racing', 'Game Role Playing',
#        'Game Simulation', 'Game Sports', 'Game Strategy', 'Game Trivia',
#        'Game Word'], dtype=object)

# %%
grouped = df_app.groupby("Category")["Ev_30_norm","Ev_60_norm"].mean()

for index in grouped[grouped["Ev_60_norm"] > 1200000].index:
    x = [-60,-30,0]
    y = [0,grouped.loc[index,"Ev_30_norm"],grouped.loc[index,"Ev_60_norm"]]
    plt.plot(x, y, label = index)
plt.annotate("Today",(0,0))
plt.xlabel('Days')
plt.ylabel('Percentage')
plt.legend()
plt.show()

# %% [markdown]
# # Ranking
# **In this section we will try to made a simple but reliable score to make global ranking**

# %%
df_app["Score"] = (df_app["Installs"]+df_app["Nb_Rating"])*df_app["Avg_Rating"]

# %%
df_app["Global_rank"] = df_app["Score"].rank(ascending = False)

# %%
df_app.sort_values(["Global_rank"]).head(60)
# Out:
#                                                      URL   Rank  \
# 14459  /application/google/com.google.android.googleq...    3.0
# 3009            /application/gmail/com.google.android.gm   10.0
# 12458  /application/google_drive/com.google.android.a...    2.0
# 3003   /application/google_chrome_fast_secure/com.and...    4.0
# 3000        /application/whatsapp_messenger/com.whatsapp    1.0
# 14478  /application/android_accessibility_suite/com.g...   22.0
# 14481  /application/google_text_to_speech/com.google....   25.0
# 15017  /application/maps_navigate_explore/com.google....    1.0
# 13457          /application/facebook/com.facebook.katana    1.0
# 14457  /application/google_play_services/com.google.a...    1.0
# 15517    /application/youtube/com.google.android.youtube    1.0
# 9499   /application/google_play_music/com.google.andr...    3.0
# 13458       /application/instagram/com.instagram.android    2.0
# 11968  /application/samsung_gallery/com.sec.android.g...   12.0
# 11957  /application/google_photos/com.google.android....    1.0
# 12476  /application/samsung_email/com.samsung.android...   20.0
# 17957   /application/subway_surfers/com.kiloo.subwaysurf    1.0
# 14465  /application/gboard_the_google_keyboard/com.go...    9.0
# 12472  /application/microsoft_onedrive/com.microsoft....   16.0
# 14872  /application/samsung_calculator/com.sec.androi...  356.0
# 3014   /application/google_duo_high_quality_video_cal...   15.0
# 3001   /application/messenger_text_and_video_chat_for...    2.0
# 12460  /application/microsoft_word_write_edit_share_d...    4.0
# 12467  /application/microsoft_excel_view_edit_create_...   11.0
# 13459         /application/snapchat/com.snapchat.android    3.0
# 10000  /application/google_news_top_world_local_news_...    4.0
# 4500   /application/google_play_games/com.google.andr...    1.0
# 14919  /application/samsung_my_files/com.sec.android....  403.0
# 14928  /application/samsung_voice_recorder/com.sec.an...  412.0
# 3029   /application/samsung_internet_browser/com.sec....   30.0
# 14460  /application/shareit_transfer_share/com.lenovo...    4.0
# 12474  /application/microsoft_powerpoint_slideshows_a...   18.0
# 3008   /application/skype_free_im_video_calls/com.sky...    9.0
# 6302   /application/samsung_health/com.sec.android.ap...    6.0
# 14471  /application/android_system_webview/com.google...   15.0
# 12478  /application/google_calendar/com.google.androi...   22.0
# 13461       /application/facebook_lite/com.facebook.lite    5.0
# 12505  /application/samsung_print_service_plugin/com....   49.0
# 14796  /application/device_care/com.samsung.android.lool  280.0
# 3036   /application/samsung_push_service/com.sec.spp....   37.0
# 1502   /application/google_play_books_ebooks_audioboo...    3.0
# 15022  /application/google_street_view/com.google.and...    6.0
# 11075  /application/samsung_one_ui_home/com.sec.andro...   79.0
# 13463  /application/google_for_g_suite/com.google.and...    7.0
# 3016       /application/hangouts/com.google.android.talk   17.0
# 12504  /application/cloud_print/com.google.android.ap...   48.0
# 14794  /application/ant_plugins_service/com.dsi.ant.p...  278.0
# 15529  /application/google_play_movies_tv/com.google....   13.0
# 3099   /application/ant_radio_service/com.dsi.ant.ser...  100.0
# 23957  /application/clash_of_clans/com.supercell.clas...    1.0
# 19957  /application/candy_crush_saga/com.king.candycr...    1.0
# 16517  /application/garena_free_fire_kalahari/com.dts...    1.0
# 9497   /application/spotify_listen_to_new_music_podca...    1.0
# 13460  /application/tiktok_make_your_day/com.zhiliaoa...    4.0
# 9997            /application/twitter/com.twitter.android    1.0
# 3006   /application/truecaller_caller_id_block_roboca...    7.0
# 23457  /application/8_ball_pool/com.miniclip.eightbal...    1.0
# 19958  /application/my_talking_tom/com.outfit7.mytalk...    2.0
# 12461  /application/adobe_acrobat_reader_pdf_viewer_e...    5.0
# 3023   /application/messages/com.google.android.apps....   24.0
#
#                                                     Name  Nb_Rating  \
# 14459                                             Google   13997467
# 3009                                               Gmail    6743557
# 12458                                       Google Drive    5081538
# 3003                        Google Chrome: Fast & Secure   19578408
# 3000                                  WhatsApp Messenger  106884902
# 14478                        Android Accessibility Suite    1830589
# 14481                              Google Text-to-Speech    1661524
# 15017                          Maps - Navigate & Explore   11175295
# 13457                                           Facebook   96409662
# 14457                               Google Play services   28257988
# 15517                                            YouTube   67255190
# 9499                                   Google Play Music    4382860
# 13458                                          Instagram   95806924
# 11968                                    Samsung Gallery    2244874
# 11957                                      Google Photos   23857790
# 12476                                      Samsung Email    1199509
# 17957                                     Subway Surfers   32200740
# 14465                       Gboard - the Google Keyboard    5043105
# 12472                                 Microsoft OneDrive    1563735
# 14872                                 Samsung Calculator     119958
# 3014               Google Duo - High Quality Video Calls    4917867
# 3001            Messenger – Text and Video Chat for Free   71185969
# **Thanks to an API on the same website we can also get more detailled information but it is limited to 100 requests per hour**
#
# **These cells will be explored later to get more information for the best ranked app in the overall ranking**

# %%
#################### HERE we will need to define which app need more information
import requests
website = "https://www.androidrank.org/api/application/"
key = "60lnc52x178li1rocmpum3829kdf6d9wt3dp7lqg7vxmqat6ov9ekcoipmqyuzpa"
bigjson = []
for url in df_app[df_app["Installs"]== df_app["Installs"].max()].URL:
    codename = url.split('/')[-1]
    search = website+codename+"?key="+key;
    response = requests.get(search)
    bigjson.append(response.json())

# %%
################## Exemple on how to navigate in the big dictionnary
test = list(filter(lambda person: person['category'] == 'Communication', bigjson))
# Out:
# {'category': 'Communication',
#  'category_rank': {'current': []},
#  'developer': {'developer_id': 'WhatsApp+Inc.', 'name': 'WhatsApp Inc.'},
#  'id': 'com.whatsapp',
#  'images': {'logo': 'https://lh3.googleusercontent.com/bYtqbOcTYOlgc6gqZ2rwb8lptHuwlNE75zYJu6Bn076-hTmvd96HH-6v7S0YUAAJXoJN',
#   'screenshots': ['https://lh3.googleusercontent.com/MMue08byixTw74ST_VkNQDUUJBgVEbjNHDYLhIuHmYhMIMJIp3KjVlnhhqZQOZUtNt8',
#    'https://lh3.googleusercontent.com/foFmwvVGIwWWXJIukN7png18lFjFgbw3K7BqIm8G-jsFgSTVtkCa-dDkFApUzbvzIvbe',
#    'https://lh3.googleusercontent.com/iLgMXFO5qEPlTffpI21zaoG51AORnfu8NPb_2SdAXYgOYcb-xDOMfCryPhVvGNjoew',
#    'https://lh3.googleusercontent.com/ElfUPGX67gv0TNQXuDxQGa5a4BYnLAZIgJJmoNoARvqlLQsKEQcNNWz-J_zqGV5vzQ',
#    'https://lh3.googleusercontent.com/wBgVA58O2xncQkksLatHGoNLI8L6o_1ZM8AC3GCScxCyaDOWOvMsMilaj1Scp3kEOIw',
#    'https://lh3.googleusercontent.com/nknhZ6--QSyZlohrv72BaPlwO2EHPvGKJY8NNACYY0IY8j4QKYATP6alT1yyMYb-35j9']},
#  'installs': {'current': {'count': '5000000000'},
#   'history': [{'count': 5000000000, 'date': '2020-02-01'},
#    {'count': 1000000000, 'date': '2015-03-12'},
#    {'count': 500000000, 'date': '2014-03-30'},
#    {'count': 100000000, 'date': '2012-11-07'},
#    {'count': 50000000, 'date': '2012-06-24'},
#    {'count': 10000000, 'date': '2012-03-19'}]},
#  'name': 'WhatsApp Messenger',
#  'price': {'current': 'Free', 'history': {}},
#  'ratings': {'current': {'count': 108328069,
#    'rank1': 10230386,
#    'rank2': 3359932,
#    'rank3': 6361658,
#    'rank4': 11982013,
#    'rank5': 76394077},
#   'history': [{'count': 401945,
#     'date': '2011-12-10',
#     'rank1': 8683,
#     'rank2': 5041,
#     'rank3': 21726,
#     'rank4': 75892,
#     'rank5': 290603},
#    {'count': 495440,
#     'date': '2012-01-31',
#     'rank1': 10793,
#     'rank2': 6195,
#     'rank3': 26770,
#     'rank4': 91557,
#     'rank5': 360125},
#    {'count': 631252,
#     'date': '2012-04-14',
#     'rank1': 14066,
#     'rank2': 7807,
#     'rank3': 33221,
#     'rank4': 111591,
#     'rank5': 464567},
#    {'count': 1001930,
#     'date': '2012-07-27',
#     'rank1': 27031,
#     'rank2': 12841,
#     'rank3': 50739,
#     'rank4': 164025,
#     'rank5': 747294},
#    {'count': 2015207,
#     'date': '2012-12-31',
#     'rank1': 67962,
#     'rank2': 28608,
#     'rank3': 100070,
#     'rank4': 302536,
#     'rank5': 1516031},
#    {'count': 2699898,
#     'date': '2013-04-14',
#     'rank1': 105582,
#     'rank2': 41040,
#     'rank3': 135175,
#     'rank4': 393357,
#     'rank5': 2024744},
#    {'count': 3929577,
#     'date': '2013-08-24',
#     'rank1': 156755,
#     'rank2': 60987,
#     'rank3': 198593,
#     'rank4': 561298,
#     'rank5': 2951944},
#    {'count': 5300866,
#     'date': '2013-12-17',
#     'rank1': 229353,
#     'rank2': 89372,
#     'rank3': 274708,
#     'rank4': 741286,
#     'rank5': 3966147},
#    {'count': 12361952,
#     'date': '2014-05-05',
#     'rank1': 640179,
#     'rank2': 312834,
#     'rank3': 734843,
#     'rank4': 1912078,
#     'rank5': 8762018},
#    {'count': 18718146,
#     'date': '2014-10-07',
#     'rank1': 947624,
#     'rank2': 498794,
#     'rank3': 1147761,
#     'rank4': 2865940,
#     'rank5': 13258027},
#    {'count': 24798806,
#     'date': '2015-03-27',
#     'rank1': 1302511,
#     'rank2': 699487,
#     'rank3': 1536818,
#     'rank4': 3780026,
#     'rank5': 17479964},
#    {'count': 29420994,
#     'date': '2015-09-02',
#     'rank1': 1524572,
#     'rank2': 817958,
#     'rank3': 1809684,
#     'rank4': 4452350,
#     'rank5': 20816430},
#    {'count': 35836095,
#     'date': '2016-03-20',
#     'rank1': 1870163,
#     'rank2': 986303,
#     'rank3': 2220523,
#     'rank4': 5431963,
#     'rank5': 25327143},
#    {'count': 41767160,
#     'date': '2016-08-16',
#     'rank1': 2188737,
#     'rank2': 1135398,
#     'rank3': 2624739,
#     'rank4': 6379111,
#     'rank5': 29439175},
#    {'count': 51281606,
#     'date': '2017-02-20',
#     'rank1': 2703416,
#     'rank2': 1375679,
#     'rank3': 3273825,
#     'rank4': 7849557,
#     'rank5': 36079129},
#    {'count': 58285922,
#     'date': '2017-09-01',
#     'rank1': 3759682,
#     'rank2': 1576335,
#     'rank3': 3718187,
#     'rank4': 8722375,
#     'rank5': 40509343},
#    {'count': 65062805,
#     'date': '2018-03-26',
#     'rank1': 4168369,
#     'rank2': 1720497,
#     'rank3': 4151944,
#     'rank4': 9581104,
#     'rank5': 45440891},
#    {'count': 70629425,
#     'date': '2018-09-22',
#     'rank1': 4428460,
#     'rank2': 1813134,
#     'rank3': 4482716,
#     'rank4': 10260903,
#     'rank5': 49644212},
#    {'count': 92096516,
#     'date': '2019-07-03',
#     'rank1': 5740916,
#     'rank2': 2248584,
#     'rank3': 5768653,
#     'rank4': 12795040,
#     'rank5': 65543323},
#    {'count': 108328066,
#     'date': '2020-04-01',
#     'rank1': 10230386,
#     'rank2': 3359932,
#     'rank3': 6361658,
#     'rank4': 11982013,
#     'rank5': 76394077}]}}
